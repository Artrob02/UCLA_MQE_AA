# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('/content/gdrive/MyDrive/ML/winequality-red.csv')

# %%
plt.figure(figsize=(12,5))
plt.plot(df['alcohol'])
plt.title('Alcohol Level across red wines')
plt.ylabel('Alcohol in %')
plt.xlabel('Red wine sample')
# Out:
# Text(0.5, 0, 'Red wine sample')

# %% [markdown]
# The graph shows the alcohol levels across 1600 red wines.
